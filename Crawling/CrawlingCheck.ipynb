# %%
import pandas as pd

# %%
deposit = pd.read_csv('deposit.csv')
deposit.head()
# Out:
#                        상품명                                               최고금리  \
# 0             국민수퍼정기예금(개인)  연1.10%2021.09.03 현재, 세전, 36개월 기준고정금리형, 만기이자지급식...
# 1             KB Star 정기예금  연 1.32%2021.09.06 현재, 세전, 36개월기준신규(또는 재예치)일 당시...
# 2               KB국민UP정기예금  연1.10%2021.09.03 현재, 세전, 11개월 초과 ~ 12개월 이하우대이율...
# 3  KB Green Wave 1.5℃ 정기예금  연 1.40%(12개월)ㆍ2021.09.03 현재, 세전, 1년제 기준 ㆍ우대이율 ...
# 4               KB국민첫재테크예금  연1.15%2021.09.03 현재, 세전, 12개월 기준우대이율 최고 연 0.2%...
#
#    상품유형                    가입기간  \
# 0  정기예금  CD금리연동형6개월, 1년, 2년, 3년
# 1  정기예금          1개월이상36개월이하월단위
# 2  정기예금                    12개월
# 3  정기예금                     1년제
# 4  정기예금               6개월, 12개월
#
#                                                 가입금액  \
# 0                   1백만원 이상원 단위. 신규계좌를 포함하여 30회까지 가능
# 1                                     1백만원 이상추가입금 불가
# 2          개인(개인사업자 포함) : 3백만원 이상법인 및 임의단체 : 3천만원 이상
# 3  1백만원 이상 1천만원 이하총 10만좌ㆍ10만좌 가입 시 판매종료불가능불가능가능가능...
# ...

# %%
deposit[deposit['예금자보호'].isnull()]
# Out:
#                             상품명 최고금리 상품유형 가입기간 가입금액  재예치 분할해지 만기예금 편리입금서비스  \
# 28                KB상호부금(자유적립식)  NaN  NaN  NaN  NaN  NaN  NaN          NaN
# 34                KB상호부금(정액적립식)  NaN  NaN  NaN  NaN  NaN  NaN          NaN
# 44  KB e-Commerce 채권양도 전용계좌(통장)  NaN  NaN  NaN  NaN  NaN  NaN          NaN
# 66                       가계당좌예금  NaN  NaN  NaN  NaN  NaN  NaN          NaN
#
#    예금담보대출 예금자보호  ... 이자계산기준일  원가일 DIY형 서비스 상품특징 거래 이용매체 우대이율요건 우대금리 예치기간 납입기간  \
# 28    NaN   NaN  ...     NaN  NaN      NaN  NaN     NaN    NaN  NaN  NaN  NaN
# 34    NaN   NaN  ...     NaN  NaN      NaN  NaN     NaN    NaN  NaN  NaN  NaN
# 44    NaN   NaN  ...     NaN  NaN      NaN  NaN     NaN    NaN  NaN  NaN  NaN
# 66    NaN   NaN  ...     NaN  NaN      NaN  NaN     NaN    NaN  NaN  NaN  NaN
#
#    적립 방법 및 금액
# 28        NaN
# 34        NaN
# 44        NaN
# 66        NaN
#
# [4 rows x 59 columns]

# %%
import json
with open('depositJson.json', 'r', encoding="UTF-8") as f:
    json_data = json.load(f)

data = json.dumps(json_data, ensure_ascii = False)
print(data)
# Out:
# [{"상품명": "국민수퍼정기예금(개인)", "최고금리": "연1.10%2021.09.03 현재, 세전, 36개월 기준고정금리형, 만기이자지급식 기준우대이율 최고 연 0.1%p 포함(자세한 우대이율 제공조건은 상품설명서 참조)", "상품유형": "정기예금", "가입기간": "CD금리연동형6개월, 1년, 2년, 3년", "가입금액": "1백만원 이상원 단위. 신규계좌를 포함하여 30회까지 가능", "재예치": "불가능", "분할해지": "가능가능. 고정금리형, 계좌별로 3회(해지 포함)까지 총 15회", "만기예금 편리입금서비스": "가능", "예금담보대출": "가능계좌잔액의 95%까지 가능", "예금자보호": "가능원금과 이자 포함 1인당 최고 5천만원까지 가능", "세제혜택": "가능비과세종합저축으로 가입 가능", "이자계산방법[세전]": "불가능", "중도해지이율": "최저 연 0.1%", "휴면예금출연": "만기일 또는 최종거래일 이후 5년이상 경과 시 ‘서민금융진흥원’으로 출연", "가입대상": null, "분할인출": null, "만기이자계산방법": null, "예금만기": null, "만기예금편리입금서비스": null, "판매좌수": null, "일부해지": null, "이자계산방법[세전, 연단위]": null, "부가서비스": null, "만기이자계산방법[세전, 연단위]": null, "원금 및이자지급방법": null, "저축방법 및 저축금액": null, "세제관련": null, "만기이자계산방법[세전]": null, "적립방법": null, "저축방법  및 저축금액": null, "재정지원금": null, "복무구분": null, "저축방법 및저축금액": null, "계약기간": null, "저축금액": null, "제휴서비스": null, "만기이자 계산방법": null, "일부인출": null, "만기앞당김 지급": null, "기타": null, "저축금액 및저축방법": null, "저축금액및 저축방법": null, "저축금액 및 저축
# ...
